# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If city is unique, add to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print city count 
len(cities)
# Out:
# 774

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | mahon
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | touros
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | meulaboh
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | coihaique
# Processing Record 14 of Set 1 | hasaki
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | uvalde
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | la ronge
# Processing Record 20 of Set 1 | mount gambier
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | abalak
# Processing Record 26 of Set 1 | raudeberg
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | san jose
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | saint-quentin
# Processing Record 33 of Set 1 | young
# Processing Record 34 of Set 1 | kupang
# Processing Record 35 of Set 1 | flinders
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | karlshus
# Processing Record 38 of Set 1 | dingle
# Processing Record 39 of Set 1 | ca mau
# Processing Record 40 of Set 1 | shimoda
# Processing Record 41 of Set 1 | kamenka
# Processing Record 42 of Set 1 | varkaus
# Processing Record 43 of Set 1 | mount isa
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | pochutla
# Processing Record 46 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | sechura
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | bathsheba
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | coahuayana
# Processing Record 5 of Set 2 | rio gallegos
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | takoradi
# Processing Record 8 of Set 2 | shenjiamen
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | saint-augustin
# Processing Record 12 of Set 2 | ustyuzhna
# Processing Record 13 of Set 2 | banda aceh
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | sakakah
# Processing Record 17 of Set 2 | katherine
# Processing Record 18 of Set 2 | new glasgow
# Processing Record 19 of Set 2 | narsaq
# Processing Record 20 of Set 2 | burgeo
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | coquimbo
# Processing Record 27 of Set 2 | bubaque
# Processing Record 28 of Set 2 | mandera
# Processing Record 29 of Set 2 | wichita falls
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | laguna de duero
# Processing Record 32 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | puerto leguizamo
# Processing Record 36 of Set 2 | el reno
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | inuvik
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | mastic beach
# Processing Record 41 of Set 2 | moose factory
# Processing Record 42 of Set 2 | anadyr
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | libreville
# Processing Record 45 of Set 2 | black forest
# Processing Record 46 of Set 2 | krasnoarmeysk
# Processing Record 47 of Set 2 | bagan
# Processing Record 48 of Set 2 | port keats
# Processing Record 49 of Set 2 | kot kapura
# Processing Record 50 of Set 2 | manokwari
# Processing Record 1 of Set 3 | pangai
# Processing Record 2 of Set 3 | ponta do sol
# Processing Record 3 of Set 3 | abu dhabi
# Processing Record 4 of Set 3 | alta floresta
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | oranjemund
# Processing Record 8 of Set 3 | harper
# Processing Record 9 of Set 3 | genhe
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | laguna
# Processing Record 12 of Set 3 | miri
# Processing Record 13 of Set 3 | nchelenge
# Processing Record 14 of Set 3 | yulara
# Processing Record 15 of Set 3 | gunnedah
# Processing Record 16 of Set 3 | port augusta
# Processing Record 17 of Set 3 | monteagudo
# Processing Record 18 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 3 | vanavara
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | muros
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 3 | cravo norte
# Processing Record 26 of Set 3 | altay
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | nikolskoye
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | iralaya
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 3 | byron bay
# Processing Record 35 of Set 3 | agogo
# Processing Record 36 of Set 3 | kalivia
# Processing Record 37 of Set 3 | basco
# Processing Record 38 of Set 3 | severo-kurilsk
# Processing Record 39 of Set 3 | alghero
# Processing Record 40 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 3 | rafai
# Processing Record 42 of Set 3 | danjiangkou
# Processing Record 43 of Set 3 | port blair
# Processing Record 44 of Set 3 | olga
# Processing Record 45 of Set 3 | jaen
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | smithers
# Processing Record 48 of Set 3 | tambovka
# Processing Record 49 of Set 3 | nioro
# Processing Record 50 of Set 3 | teeli
# Processing Record 1 of Set 4 | richards bay
# Processing Record 2 of Set 4 | castro
# Processing Record 3 of Set 4 | longkou
# Processing Record 4 of Set 4 | havre-saint-pierre
# Processing Record 5 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 4 | luganville
# Processing Record 7 of Set 4 | muzhi
# Processing Record 8 of Set 4 | tuatapere
# Processing Record 9 of Set 4 | koungheul
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | maceio
# Processing Record 12 of Set 4 | chernyshevskiy
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | sim
# Processing Record 19 of Set 4 | half moon bay
# Processing Record 20 of Set 4 | vilhena
# Processing Record 21 of Set 4 | baghdad
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | buala
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | ashqelon
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | maragogi
# Processing Record 29 of Set 4 | kiunga
# Processing Record 30 of Set 4 | magistralnyy
# Processing Record 31 of Set 4 | zatoka
# Processing Record 32 of Set 4 | agadez
# Processing Record 33 of Set 4 | asha
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | coffs harbour
# Processing Record 36 of Set 4 | guangyuan
# Processing Record 37 of Set 4 | canon city
# Processing Record 38 of Set 4 | bad sankt leonhard
# City not found. Skipping...
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | severodvinsk
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | port lincoln
# Processing Record 43 of Set 4 | torbay
# Processing Record 44 of Set 4 | negombo
# Processing Record 45 of Set 4 | cap malheureux
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | barabinsk
# Processing Record 49 of Set 4 | poum
# Processing Record 50 of Set 4 | college
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | duncan
# Processing Record 4 of Set 5 | mwinilunga
# Processing Record 5 of Set 5 | beisfjord
# Processing Record 6 of Set 5 | calabozo
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | waipawa
# Processing Record 9 of Set 5 | taltal
# Processing Record 10 of Set 5 | tarboro
# Processing Record 11 of Set 5 | zambezi
# Processing Record 12 of Set 5 | vao
# Processing Record 13 of Set 5 | la mana
# Processing Record 14 of Set 5 | kaeo
# Processing Record 15 of Set 5 | korla
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | tezu
# Processing Record 18 of Set 5 | chicama
# Processing Record 19 of Set 5 | trairi
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | ocampo
# Processing Record 22 of Set 5 | nicoya
# Processing Record 23 of Set 5 | beringovskiy
# Processing Record 24 of Set 5 | sulangan
# Processing Record 25 of Set 5 | haines junction
# Processing Record 26 of Set 5 | morondava
# Processing Record 27 of Set 5 | dourbali
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | vanimo
# Processing Record 30 of Set 5 | sharkan
# Processing Record 31 of Set 5 | bredasdorp
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | atasu
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | gobabis
# Processing Record 36 of Set 5 | san clemente
# Processing Record 37 of Set 5 | cockburn town
# Processing Record 38 of Set 5 | skawina
# Processing Record 39 of Set 5 | kapit
# Processing Record 40 of Set 5 | acapulco
# Processing Record 41 of Set 5 | yerazgavors
# Processing Record 42 of Set 5 | qaqortoq
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | san patricio
# Processing Record 45 of Set 5 | porbandar
# Processing Record 46 of Set 5 | palauig
# Processing Record 47 of Set 5 | kalmunai
# Processing Record 48 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 5 | le vauclin
# Processing Record 50 of Set 5 | tequisquiapan
# Processing Record 1 of Set 6 | tecoanapa
# Processing Record 2 of Set 6 | novoagansk
# Processing Record 3 of Set 6 | iaciara
# Processing Record 4 of Set 6 | besikduzu
# Processing Record 5 of Set 6 | evensk
# Processing Record 6 of Set 6 | campbell river
# Processing Record 7 of Set 6 | avarua
# Processing Record 8 of Set 6 | chapais
# Processing Record 9 of Set 6 | bengkulu
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | paamiut
# Processing Record 12 of Set 6 | eyrarbakki
# Processing Record 13 of Set 6 | dire dawa
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | wanning
# Processing Record 16 of Set 6 | sasovo
# Processing Record 17 of Set 6 | eregli
# Processing Record 18 of Set 6 | anito
# Processing Record 19 of Set 6 | sisimiut
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | atar
# Processing Record 22 of Set 6 | kenai
# Processing Record 23 of Set 6 | tilichiki
# Processing Record 24 of Set 6 | saldanha
# Processing Record 25 of Set 6 | saint george
# Processing Record 26 of Set 6 | benguela
# Processing Record 27 of Set 6 | khobi
# Processing Record 28 of Set 6 | arlit
# Processing Record 29 of Set 6 | sorland
# Processing Record 30 of Set 6 | kimbe
# Processing Record 31 of Set 6 | bucerias
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | kapoeta
# Processing Record 34 of Set 6 | pokrovka
# Processing Record 35 of Set 6 | dodge city
# Processing Record 36 of Set 6 | imbituba
# Processing Record 37 of Set 6 | ballstad
# City not found. Skipping...
# Processing Record 38 of Set 6 | mbandaka
# Processing Record 39 of Set 6 | hamilton
# Processing Record 40 of Set 6 | eskisehir
# Processing Record 41 of Set 6 | kaseda
# Processing Record 42 of Set 6 | villacarrillo
# Processing Record 43 of Set 6 | carikar
# City not found. Skipping...
# Processing Record 44 of Set 6 | mahebourg
# Processing Record 45 of Set 6 | kindu
# Processing Record 46 of Set 6 | yar-sale
# Processing Record 47 of Set 6 | havoysund
# Processing Record 48 of Set 6 | san quintin
# Processing Record 49 of Set 6 | andenes
# Processing Record 50 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 7 | iranshahr
# Processing Record 2 of Set 7 | nikolayevsk-na-amure
# Processing Record 3 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 4 of Set 7 | kysyl-syr
# Processing Record 5 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 7 | birao
# Processing Record 7 of Set 7 | sao joao da barra
# Processing Record 8 of Set 7 | amahai
# Processing Record 9 of Set 7 | salvacion
# Processing Record 10 of Set 7 | tiznit
# Processing Record 11 of Set 7 | necochea
# Processing Record 12 of Set 7 | isagarh
# Processing Record 13 of Set 7 | mehamn
# Processing Record 14 of Set 7 | pafos
# Processing Record 15 of Set 7 | faya
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | moerai
# Processing Record 18 of Set 7 | batagay
# Processing Record 19 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 20 of Set 7 | abnub
# Processing Record 21 of Set 7 | komsomolskiy
# Processing Record 22 of Set 7 | bafra
# Processing Record 23 of Set 7 | taoudenni
# Processing Record 24 of Set 7 | tura
# Processing Record 25 of Set 7 | talnakh
# Processing Record 26 of Set 7 | beyneu
# Processing Record 27 of Set 7 | teahupoo
# Processing Record 28 of Set 7 | zurrieq
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | jurado
# Processing Record 31 of Set 7 | phangnga
# Processing Record 32 of Set 7 | ojinaga
# Processing Record 33 of Set 7 | karratha
# Processing Record 34 of Set 7 | markova
# Processing Record 35 of Set 7 | khatanga
# Processing Record 36 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 37 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 7 | doha
# Processing Record 39 of Set 7 | carndonagh
# Processing Record 40 of Set 7 | abu samrah
# Processing Record 41 of Set 7 | la palma
# Processing Record 42 of Set 7 | ribeira brava
# Processing Record 43 of Set 7 | namatanai
# Processing Record 44 of Set 7 | borovoy
# Processing Record 45 of Set 7 | esperance
# Processing Record 46 of Set 7 | havelock
# Processing Record 47 of Set 7 | sukumo
# Processing Record 48 of Set 7 | marrakesh
# Processing Record 49 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 7 | ambon
# Processing Record 1 of Set 8 | te anau
# Processing Record 2 of Set 8 | diebougou
# Processing Record 3 of Set 8 | avera
# Processing Record 4 of Set 8 | nyurba
# Processing Record 5 of Set 8 | garm
# City not found. Skipping...
# Processing Record 6 of Set 8 | barabai
# Processing Record 7 of Set 8 | rapid valley
# Processing Record 8 of Set 8 | faanui
# Processing Record 9 of Set 8 | kahului
# Processing Record 10 of Set 8 | kununurra
# Processing Record 11 of Set 8 | kolpashevo
# Processing Record 12 of Set 8 | bastia
# Processing Record 13 of Set 8 | port moresby
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | river falls
# Processing Record 16 of Set 8 | vardo
# Processing Record 17 of Set 8 | lagoa
# Processing Record 18 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 19 of Set 8 | doctor juan leon mallorquin
# Processing Record 20 of Set 8 | belaya gora
# Processing Record 21 of Set 8 | hurghada
# Processing Record 22 of Set 8 | khani
# Processing Record 23 of Set 8 | ramona
# Processing Record 24 of Set 8 | denpasar
# Processing Record 25 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 26 of Set 8 | ati
# Processing Record 27 of Set 8 | marawi
# Processing Record 28 of Set 8 | bousse
# Processing Record 29 of Set 8 | lalibela
# Processing Record 30 of Set 8 | kulhudhuffushi
# Processing Record 31 of Set 8 | bezhetsk
# Processing Record 32 of Set 8 | krk
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | preeceville
# Processing Record 35 of Set 8 | akyab
# Processing Record 36 of Set 8 | la seyne-sur-mer
# Processing Record 37 of Set 8 | princeton
# Processing Record 38 of Set 8 | aklavik
# Processing Record 39 of Set 8 | cayenne
# Processing Record 40 of Set 8 | dwarka
# Processing Record 41 of Set 8 | morrope
# Processing Record 42 of Set 8 | praia da vitoria
# Processing Record 43 of Set 8 | ouadda
# Processing Record 44 of Set 8 | awjilah
# Processing Record 45 of Set 8 | adrar
# Processing Record 46 of Set 8 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 47 of Set 8 | tomatlan
# Processing Record 48 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 8 | mitsamiouli
# Processing Record 50 of Set 8 | malmesbury
# Processing Record 1 of Set 9 | santa rosa
# Processing Record 2 of Set 9 | orangeburg
# Processing Record 3 of Set 9 | burns lake
# Processing Record 4 of Set 9 | youghal
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | kisangani
# Processing Record 7 of Set 9 | okhotsk
# Processing Record 8 of Set 9 | eenhana
# Processing Record 9 of Set 9 | pevek
# Processing Record 10 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 9 | ilulissat
# Processing Record 12 of Set 9 | halifax
# Processing Record 13 of Set 9 | dakar
# Processing Record 14 of Set 9 | kalabugao
# City not found. Skipping...
# Processing Record 15 of Set 9 | bac lieu
# Processing Record 16 of Set 9 | cookeville
# Processing Record 17 of Set 9 | hun
# Processing Record 18 of Set 9 | acajutla
# Processing Record 19 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 9 | huarmey
# Processing Record 21 of Set 9 | capitola
# Processing Record 22 of Set 9 | kaabong
# Processing Record 23 of Set 9 | krasnoselkup
# Processing Record 24 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 9 | southport
# Processing Record 26 of Set 9 | mossendjo
# Processing Record 27 of Set 9 | mayo
# Processing Record 28 of Set 9 | sergeyevka
# Processing Record 29 of Set 9 | riyadh
# Processing Record 30 of Set 9 | ucluelet
# Processing Record 31 of Set 9 | kabo
# Processing Record 32 of Set 9 | saint-joseph
# Processing Record 33 of Set 9 | taber
# Processing Record 34 of Set 9 | inirida
# Processing Record 35 of Set 9 | toledo
# Processing Record 36 of Set 9 | les escoumins
# Processing Record 37 of Set 9 | winchester
# Processing Record 38 of Set 9 | lasa
# Processing Record 39 of Set 9 | rawson
# Processing Record 40 of Set 9 | kehychivka
# Processing Record 41 of Set 9 | sorong
# Processing Record 42 of Set 9 | lagos
# Processing Record 43 of Set 9 | grindavik
# Processing Record 44 of Set 9 | gat
# Processing Record 45 of Set 9 | cumaral
# Processing Record 46 of Set 9 | nantucket
# Processing Record 47 of Set 9 | tijuana
# Processing Record 48 of Set 9 | ketchikan
# Processing Record 49 of Set 9 | mackay
# Processing Record 50 of Set 9 | azua
# Processing Record 1 of Set 10 | cojutepeque
# Processing Record 2 of Set 10 | vestmannaeyjar
# Processing Record 3 of Set 10 | biltine
# Processing Record 4 of Set 10 | tambun
# Processing Record 5 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 10 | bisho
# Processing Record 7 of Set 10 | otavi
# Processing Record 8 of Set 10 | vostok
# Processing Record 9 of Set 10 | airai
# Processing Record 10 of Set 10 | yekimovichi
# Processing Record 11 of Set 10 | fukuma
# Processing Record 12 of Set 10 | pindiga
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | cabedelo
# Processing Record 15 of Set 10 | berdigestyakh
# Processing Record 16 of Set 10 | eyl
# Processing Record 17 of Set 10 | alihe
# Processing Record 18 of Set 10 | broome
# Processing Record 19 of Set 10 | ilo
# Processing Record 20 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 21 of Set 10 | yoichi
# Processing Record 22 of Set 10 | vanderhoof
# Processing Record 23 of Set 10 | zarakes
# City not found. Skipping...
# Processing Record 24 of Set 10 | galveston
# Processing Record 25 of Set 10 | skibbereen
# Processing Record 26 of Set 10 | bud
# Processing Record 27 of Set 10 | saint-georges
# Processing Record 28 of Set 10 | diffa
# Processing Record 29 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 30 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 31 of Set 10 | nueve de julio
# Processing Record 32 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 10 | chor
# Processing Record 34 of Set 10 | namibe
# Processing Record 35 of Set 10 | alyangula
# Processing Record 36 of Set 10 | tarpon springs
# Processing Record 37 of Set 10 | sedalia
# Processing Record 38 of Set 10 | adolfo lopez mateos
# Processing Record 39 of Set 10 | kruisfontein
# Processing Record 40 of Set 10 | codrington
# Processing Record 41 of Set 10 | alice springs
# Processing Record 42 of Set 10 | esso
# Processing Record 43 of Set 10 | catuday
# Processing Record 44 of Set 10 | paraiso
# Processing Record 45 of Set 10 | stornoway
# Processing Record 46 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 10 | mecca
# Processing Record 48 of Set 10 | krasnyy chikoy
# Processing Record 49 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 10 | saint-francois
# Processing Record 1 of Set 11 | tuy hoa
# Processing Record 2 of Set 11 | jampur
# Processing Record 3 of Set 11 | indramayu
# Processing Record 4 of Set 11 | miquelon
# Processing Record 5 of Set 11 | zhangye
# Processing Record 6 of Set 11 | san policarpo
# Processing Record 7 of Set 11 | isla mujeres
# Processing Record 8 of Set 11 | morant bay
# Processing Record 9 of Set 11 | burica
# City not found. Skipping...
# Processing Record 10 of Set 11 | hofn
# Processing Record 11 of Set 11 | herat
# Processing Record 12 of Set 11 | mana
# Processing Record 13 of Set 11 | chuncheng
# Processing Record 14 of Set 11 | boguchany
# Processing Record 15 of Set 11 | vila
# Processing Record 16 of Set 11 | aripuana
# Processing Record 17 of Set 11 | soyo
# Processing Record 18 of Set 11 | high level
# Processing Record 19 of Set 11 | telixtlahuaca
# City not found. Skipping...
# Processing Record 20 of Set 11 | den helder
# Processing Record 21 of Set 11 | waitati
# Processing Record 22 of Set 11 | acarau
# Processing Record 23 of Set 11 | marataizes
# Processing Record 24 of Set 11 | nsoko
# Processing Record 25 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 11 | calama
# Processing Record 27 of Set 11 | jasper
# Processing Record 28 of Set 11 | nishihara
# Processing Record 29 of Set 11 | ikot ekpene
# Processing Record 30 of Set 11 | tumut
# Processing Record 31 of Set 11 | north battleford
# Processing Record 32 of Set 11 | portland
# Processing Record 33 of Set 11 | jobat
# Processing Record 34 of Set 11 | suluq
# Processing Record 35 of Set 11 | san buenaventura
# Processing Record 36 of Set 11 | lubango
# Processing Record 37 of Set 11 | lesnoy
# Processing Record 38 of Set 11 | ambilobe
# Processing Record 39 of Set 11 | am timan
# Processing Record 40 of Set 11 | pakxe
# Processing Record 41 of Set 11 | aras
# Processing Record 42 of Set 11 | waddan
# Processing Record 43 of Set 11 | pacific grove
# Processing Record 44 of Set 11 | kropotkin
# Processing Record 45 of Set 11 | australind
# Processing Record 46 of Set 11 | merritt island
# Processing Record 47 of Set 11 | jati
# Processing Record 48 of Set 11 | netanya
# Processing Record 49 of Set 11 | calvinia
# Processing Record 50 of Set 11 | henties bay
# Processing Record 1 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 12 | zonguldak
# Processing Record 3 of Set 12 | zhigalovo
# Processing Record 4 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 5 of Set 12 | sangar
# Processing Record 6 of Set 12 | shieli
# Processing Record 7 of Set 12 | iqaluit
# Processing Record 8 of Set 12 | gravdal
# Processing Record 9 of Set 12 | srednekolymsk
# Processing Record 10 of Set 12 | marquette
# Processing Record 11 of Set 12 | ishikari
# Processing Record 12 of Set 12 | teguise
# Processing Record 13 of Set 12 | tocok
# Processing Record 14 of Set 12 | kichmengskiy gorodok
# Processing Record 15 of Set 12 | broken hill
# Processing Record 16 of Set 12 | svecha
# Processing Record 17 of Set 12 | irbit
# Processing Record 18 of Set 12 | axim
# Processing Record 19 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 12 | dawlatabad
# Processing Record 21 of Set 12 | norrkoping
# Processing Record 22 of Set 12 | port-gentil
# Processing Record 23 of Set 12 | san luis de la paz
# Processing Record 24 of Set 12 | onguday
# Processing Record 25 of Set 12 | huntsville
# Processing Record 26 of Set 12 | pimentel
# Processing Record 27 of Set 12 | coari
# Processing Record 28 of Set 12 | yumen
# Processing Record 29 of Set 12 | tyler
# Processing Record 30 of Set 12 | samarai
# Processing Record 31 of Set 12 | birobidzhan
# Processing Record 32 of Set 12 | riverton
# Processing Record 33 of Set 12 | fenoarivo
# Processing Record 34 of Set 12 | sobolevo
# Processing Record 35 of Set 12 | pangoa
# Processing Record 36 of Set 12 | warrington
# Processing Record 37 of Set 12 | sinnamary
# Processing Record 38 of Set 12 | inyonga
# Processing Record 39 of Set 12 | rio grande
# Processing Record 40 of Set 12 | yeppoon
# Processing Record 41 of Set 12 | fort saint james
# Processing Record 42 of Set 12 | umm kaddadah
# Processing Record 43 of Set 12 | ukiah
# Processing Record 44 of Set 12 | berlevag
# Processing Record 45 of Set 12 | zandvoort
# Processing Record 46 of Set 12 | puerto padre
# Processing Record 47 of Set 12 | san cristobal
# Processing Record 48 of Set 12 | leningradskiy
# Processing Record 49 of Set 12 | ancud
# Processing Record 50 of Set 12 | murgab
# Processing Record 1 of Set 13 | borogontsy
# Processing Record 2 of Set 13 | ayagoz
# Processing Record 3 of Set 13 | mendi
# Processing Record 4 of Set 13 | mao
# Processing Record 5 of Set 13 | tautira
# Processing Record 6 of Set 13 | athabasca
# Processing Record 7 of Set 13 | adre
# Processing Record 8 of Set 13 | diamantino
# Processing Record 9 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 13 | melville
# Processing Record 11 of Set 13 | juegang
# Processing Record 12 of Set 13 | gwembe
# Processing Record 13 of Set 13 | labuan
# Processing Record 14 of Set 13 | marondera
# Processing Record 15 of Set 13 | jacareacanga
# Processing Record 16 of Set 13 | visby
# Processing Record 17 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 13 | port macquarie
# Processing Record 20 of Set 13 | geghamasar
# Processing Record 21 of Set 13 | burnie
# Processing Record 22 of Set 13 | makakilo city
# Processing Record 23 of Set 13 | mopipi
# Processing Record 24 of Set 13 | angoche
# Processing Record 25 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 13 | anloga
# Processing Record 27 of Set 13 | pinawa
# Processing Record 28 of Set 13 | hualmay
# Processing Record 29 of Set 13 | souillac
# Processing Record 30 of Set 13 | westport
# Processing Record 31 of Set 13 | harqalah
# Processing Record 32 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 13 | merauke
# Processing Record 34 of Set 13 | parras
# City not found. Skipping...
# Processing Record 35 of Set 13 | dickinson
# Processing Record 36 of Set 13 | tweed
# Processing Record 37 of Set 13 | nichinan
# Processing Record 38 of Set 13 | dhidhdhoo
# Processing Record 39 of Set 13 | concordia
# Processing Record 40 of Set 13 | rocha
# Processing Record 41 of Set 13 | canora
# Processing Record 42 of Set 13 | nakamura
# Processing Record 43 of Set 13 | melendugno
# Processing Record 44 of Set 13 | shingu
# Processing Record 45 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 13 | serenje
# Processing Record 48 of Set 13 | galesong
# Processing Record 49 of Set 13 | paredon
# Processing Record 50 of Set 13 | calatayud
# Processing Record 1 of Set 14 | chingirlau
# Processing Record 2 of Set 14 | souda
# Processing Record 3 of Set 14 | japura
# Processing Record 4 of Set 14 | sovetskiy
# Processing Record 5 of Set 14 | agirish
# Processing Record 6 of Set 14 | aguimes
# Processing Record 7 of Set 14 | sayyan
# Processing Record 8 of Set 14 | antsohihy
# Processing Record 9 of Set 14 | vuktyl
# Processing Record 10 of Set 14 | northam
# Processing Record 11 of Set 14 | sur
# Processing Record 12 of Set 14 | namuac
# Processing Record 13 of Set 14 | vila velha
# Processing Record 14 of Set 14 | houston
# Processing Record 15 of Set 14 | jaisinghnagar
# Processing Record 16 of Set 14 | bonavista
# Processing Record 17 of Set 14 | isangel
# Processing Record 18 of Set 14 | itarema
# Processing Record 19 of Set 14 | ostersund
# Processing Record 20 of Set 14 | dali
# Processing Record 21 of Set 14 | barreirinhas
# Processing Record 22 of Set 14 | asau
# Processing Record 23 of Set 14 | powell river
# Processing Record 24 of Set 14 | puerto madryn
# Processing Record 25 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 14 | parana
# Processing Record 27 of Set 14 | mandalgovi
# Processing Record 28 of Set 14 | turukhansk
# Processing Record 29 of Set 14 | jiuquan
# Processing Record 30 of Set 14 | nanortalik
# Processing Record 31 of Set 14 | viedma
# Processing Record 32 of Set 14 | winneba
# Processing Record 33 of Set 14 | aasiaat
# Processing Record 34 of Set 14 | vydrino
# Processing Record 35 of Set 14 | shvartsevskiy
# Processing Record 36 of Set 14 | syracuse
# Processing Record 37 of Set 14 | jinchang
# Processing Record 38 of Set 14 | ampanihy
# Processing Record 39 of Set 14 | cocobeach
# Processing Record 40 of Set 14 | vitkov
# Processing Record 41 of Set 14 | horadiz
# Processing Record 42 of Set 14 | krasnyy mayak
# City not found. Skipping...
# Processing Record 43 of Set 14 | sault sainte marie
# Processing Record 44 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 14 | sao miguel do araguaia
# Processing Record 46 of Set 14 | santona
# Processing Record 47 of Set 14 | srandakan
# Processing Record 48 of Set 14 | ixtapa
# Processing Record 49 of Set 14 | shuangcheng
# Processing Record 50 of Set 14 | lipari
# Processing Record 1 of Set 15 | san jeronimo
# Processing Record 2 of Set 15 | garden city
# Processing Record 3 of Set 15 | tazovskiy
# Processing Record 4 of Set 15 | manuk mangkaw
# Processing Record 5 of Set 15 | cozumel
# Processing Record 6 of Set 15 | araouane
# Processing Record 7 of Set 15 | amalapuram
# Processing Record 8 of Set 15 | lerici
# Processing Record 9 of Set 15 | ribas do rio pardo
# Processing Record 10 of Set 15 | mikhaylovka
# Processing Record 11 of Set 15 | grand forks
# Processing Record 12 of Set 15 | sistranda
# Processing Record 13 of Set 15 | marsh harbour
# Processing Record 14 of Set 15 | alugan
# Processing Record 15 of Set 15 | dzhebariki-khaya
# Processing Record 16 of Set 15 | bitung
# Processing Record 17 of Set 15 | kholodnyy
# Processing Record 18 of Set 15 | tigil
# Processing Record 19 of Set 15 | kabinda
# Processing Record 20 of Set 15 | greymouth
# Processing Record 21 of Set 15 | rolandia
# Processing Record 22 of Set 15 | harstad
# Processing Record 23 of Set 15 | darhan
# Processing Record 24 of Set 15 | kosh-agach
# Processing Record 25 of Set 15 | marovoay
# Processing Record 26 of Set 15 | evans
# Processing Record 27 of Set 15 | batsfjord
# Processing Record 28 of Set 15 | tual
# Processing Record 29 of Set 15 | jutai
# Processing Record 30 of Set 15 | san javier
# Processing Record 31 of Set 15 | muroto
# Processing Record 32 of Set 15 | nurobod
# Processing Record 33 of Set 15 | trenton
# Processing Record 34 of Set 15 | perove
# Processing Record 35 of Set 15 | sambava
# Processing Record 36 of Set 15 | tolaga bay
# Processing Record 37 of Set 15 | kaduqli
# Processing Record 38 of Set 15 | derzhavinsk
# Processing Record 39 of Set 15 | opuwo
# Processing Record 40 of Set 15 | hit
# Processing Record 41 of Set 15 | vorontsovka
# Processing Record 42 of Set 15 | novyye lyady
# Processing Record 43 of Set 15 | plastun
# Processing Record 44 of Set 15 | urengoy
# Processing Record 45 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 15 | gonen
# Processing Record 47 of Set 15 | terre haute
# Processing Record 48 of Set 15 | karatuzskoye
# Processing Record 49 of Set 15 | linguere
# Processing Record 50 of Set 15 | tombouctou
# Processing Record 1 of Set 16 | nicolas bravo
# Processing Record 2 of Set 16 | wagga wagga
# Processing Record 3 of Set 16 | khasan
# Processing Record 4 of Set 16 | kirakira
# Processing Record 5 of Set 16 | ellenabad
# Processing Record 6 of Set 16 | pangody
# Processing Record 7 of Set 16 | sheltozero
# Processing Record 8 of Set 16 | pompeu
# Processing Record 9 of Set 16 | warren
# Processing Record 10 of Set 16 | palmer
# Processing Record 11 of Set 16 | grand gaube
# Processing Record 12 of Set 16 | along
# Processing Record 13 of Set 16 | nelson bay
# Processing Record 14 of Set 16 | mozarlandia
# Processing Record 15 of Set 16 | hirara
# Processing Record 16 of Set 16 | rypefjord
# Processing Record 17 of Set 16 | acurenam
# Processing Record 18 of Set 16 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 19 of Set 16 | finschhafen
# Processing Record 20 of Set 16 | tlahualilo
# City not found. Skipping...
# Processing Record 21 of Set 16 | bilibino
# Processing Record 22 of Set 16 | chachapoyas
# Processing Record 23 of Set 16 | nakhon nayok
# Processing Record 24 of Set 16 | saint anthony
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Reorder columns in DataFrame
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     68.09        88          18
# 1       Rikitea      PF -23.1203 -134.9692     77.27        75          82
# 2       Kavieng      PG  -2.5744  150.7967     81.41        75          87
# 3         Mahon      ES  39.8885    4.2658     52.36        82          20
# 4       Ushuaia      AR -54.8000  -68.3000     60.08        68         100
# 5  Punta Arenas      CL -53.1500  -70.9167     57.11        58         100
# 6        Touros      BR  -5.1989  -35.4608     81.61        68          96
# 7    Sao Filipe      CV  14.8961  -24.4956     71.31        71         100
# 8         Kapaa      US  22.0752 -159.3190     69.48        97          31
# 9      Meulaboh      ID   4.1363   96.1285     78.48        87          97
#
#    Wind Speed Current Description
# 0       15.59          few clouds
# 1       12.50       broken clouds
# 2        4.47     overcast clouds
# 3        9.22          few clouds
# 4        3.83     overcast clouds
# 5        9.64     overcast clouds
# 6        7.76     overcast clouds
# 7        8.86     overcast clouds
# 8        5.01          light rain
# 9        2.59     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
